# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## creating DataFrame

# %%
#using list

student = [
    [100, 80, 10],
    [90, 50, 7],
    [130, 100, 15],
    [70, 40, 5],
]

pd.DataFrame(student, columns=['iq', 'marks', 'package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     50        7
# 2  130    100       15
# 3   70     40        5

# %%
#using dict

student = {
    'iq': [100, 90, 130, 70],
    'marks': [80, 50, 100, 40],
    'package': [10, 7, 15, 5],
}

pd.DataFrame(student)
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     50        7
# 2  130    100       15
# 3   70     40        5

# %% [markdown]
# ### using read_csv

# %%
movies = pd.read_csv('movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ## DataFrame Attributes and Method

# %%
# shape
movies.shape
# Out:
# (1629, 18)

# %%
# dtype
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
# index
movies.index
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
ipl.loc[[0,949]].index
# Out:
# Index([0, 949], dtype='int64')

# %%
#columns
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
ipl.columns[[5,0]]
# Out:
# Index(['Team1', 'ID'], dtype='object')

# %%
#values

movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
#head and tail

ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl.tail(2)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 948              Kings XI Punjab    Chennai Super Kings
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver            WinningTeam WonBy  Margin method  \
# 948          bat         N    Chennai Super Kings  Runs    33.0    NaN
# 949        field         N  Kolkata Knight Riders  Runs   140.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 948      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# ...

# %%
#sample

ipl.sample()
# Out:
#         ID    City        Date Season MatchNumber           Team1  \
# 5  1304115  Mumbai  2022-05-21   2022          69  Delhi Capitals
#
#             Team2                     Venue      TossWinner TossDecision  \
# 5  Mumbai Indians  Wankhede Stadium, Mumbai  Mumbai Indians        field
#
#   SuperOver     WinningTeam    WonBy  Margin method Player_of_Match  \
# 5         N  Mumbai Indians  Wickets     5.0    NaN       JJ Bumrah
#
#                                         Team1Players  \
# 5  ['PP Shaw', 'DA Warner', 'MR Marsh', 'RR Pant'...
#
#                                         Team2Players      Umpire1  \
# 5  ['Ishan Kishan', 'RG Sharma', 'D Brevis', 'Til...  Nitin Menon
#
#         Umpire2
# 5  Tapan Sharma

# %%
#info***

ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#describe

ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
#isnull
movies[movies.isnull()].sum()
# Out:
# title_x               0
# imdb_id               0
# poster_path           0
# wiki_link             0
# title_y               0
# original_title        0
# is_adult            0.0
# year_of_release     0.0
# runtime               0
# genres                0
# imdb_rating         0.0
# imdb_votes          0.0
# story                 0
# summary               0
# tagline               0
# actors                0
# wins_nominations      0
# release_date          0
# dtype: object

# %%
ipl.duplicated().sum()
# Out:
# np.int64(0)

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl.rename(columns={'MatchNumber':'Match No'})
# Out:
#           ID        City        Date   Season     Match No  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ## Math method

# %%
#sum axis argument

df = pd.DataFrame({
    "Runs": [10, 20, 30, 40],
    "Wickets": [1, 2, 1, 3]
})

# %%
df.sum()
# Out:
# Runs       100
# Wickets      7
# dtype: int64

# %%
df.max(axis=1)
df.min()
df.std()
df.var()
# Out:
# Runs       166.666667
# Wickets      0.916667
# dtype: float64

# %% [markdown]
# ### selecting cols from a dataframe

# %%
#single cols
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
movies[['title_x', 'actors']]
# Out:
#                                    title_x  \
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...                                    ...
# 1624                 Tera Mera Saath Rahen
# 1625                  Yeh Zindagi Ka Safar
# 1626                       Sabse Bada Sukh
# 1627                                 Daaka
# 1628                              Humsafar
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...                                                 ...
# ...

# %% [markdown]
# ### selecting row from a dataframe

# %%
# iloc
# loc

#single row

movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
#fancy indexing

movies.iloc[[4,6,7]]
# Out:
#            title_x    imdb_id  \
# 4  Evening Shadows  tt6028796
# 6    Fraud Saiyaan  tt5013008
# 7       Bombairiya  tt4971258
#
#                                          poster_path  \
# 4                                                NaN
# 6  https://upload.wikimedia.org/wikipedia/en/thum...
# 7  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                        wiki_link          title_y  \
# 4  https://en.wikipedia.org/wiki/Evening_Shadows  Evening Shadows
# 6    https://en.wikipedia.org/wiki/Fraud_Saiyaan    Fraud Saiyaan
# 7       https://en.wikipedia.org/wiki/Bombairiya       Bombairiya
#
#     original_title  is_adult  year_of_release runtime              genres  \
# 4  Evening Shadows         0             2018     102               Drama
# 6    Fraud Saiyyan         0             2019     109        Comedy|Drama
# 7       Bombairiya         0             2019     104  Comedy|Crime|Drama
#
# ...

# %%
#loc

movies.loc[[4,5,6]]
# Out:
#            title_x    imdb_id  \
# 4  Evening Shadows  tt6028796
# 5      Soni (film)  tt6078866
# 6    Fraud Saiyaan  tt5013008
#
#                                          poster_path  \
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# 6  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                        wiki_link          title_y  \
# 4  https://en.wikipedia.org/wiki/Evening_Shadows  Evening Shadows
# 5      https://en.wikipedia.org/wiki/Soni_(film)             Soni
# 6    https://en.wikipedia.org/wiki/Fraud_Saiyaan    Fraud Saiyaan
#
#     original_title  is_adult  year_of_release runtime        genres  \
# 4  Evening Shadows         0             2018     102         Drama
# 5             Soni         0             2018      97         Drama
# 6    Fraud Saiyyan         0             2019     109  Comedy|Drama
#
# ...

# %% [markdown]
# ## Selecting both rows and cols

# %%
ipl.iloc[0:3, 0:3]
# Out:
#         ID       City        Date
# 0  1312200  Ahmedabad  2022-05-29
# 1  1312199  Ahmedabad  2022-05-27
# 2  1312198    Kolkata  2022-05-25

# %% [markdown]
# ## Filtering a DataFrame

# %%
# find all the final winner

mask = ipl['MatchNumber'] == 'final'
new_df = ipl[mask]
new_df[['Season', 'WinningTeam']]


ipl[ipl['MatchNumber'] == 'final'][['Season', 'WinningTeam']]
# Out:
# Empty DataFrame
# Columns: [Season, WinningTeam]
# Index: []

# %%
# how many super over finishes have occure

ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %% [markdown]
# # how many matches has csk won in kolkata

# %%
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super King')]
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2]
# Index: []

# %%
#toss winner in match winner in percentage

ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]
# Out:
# 489

# %%
#moves with rating higher then 8 and votes > 10000


movies[(movies['imdb_rating'] > 8.5) & (movies['imdb_votes'] > 10000)]
# Out:
# Empty DataFrame
# Columns: [title_x, imdb_id, poster_path, wiki_link, title_y, original_title, is_adult, year_of_release, runtime, genres, imdb_rating, imdb_votes, story, summary, tagline, actors, wins_nominations, release_date]
# Index: []

# %% [markdown]
# ## Session 18

# %% [markdown]
# ### most important function

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#value_counts (series and dataframe)

ipl['MatchNumber'].value_counts()
# Out:
# MatchNumber
# Final                 15
# 41                    15
# 40                    15
# 43                    15
# 46                    15
#                       ..
# Qualifier              4
# Elimination Final      3
# 72                     2
# 71                     2
# 3rd Place Play-Off     1
# Name: count, Length: 80, dtype: int64

# %%
#toss decide plot

ipl['TossDecision'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
#how many matches each team has play

(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %% [markdown]
# ### sort_values(s + d)

# %%
x = pd.Series([5,4,7,33,7,86])

x.sort_values(ascending=False)
# Out:
# 5    86
# 3    33
# 2     7
# 4     7
# 0     5
# 1     4
# dtype: int64

# %%
ipl.sort_values('Team1')
# Out:
#           ID       City        Date   Season MatchNumber                Team1  \
# 676   548332    Chennai  2012-04-21     2012          26  Chennai Super Kings
# 531   733971     Ranchi  2014-05-02     2014          21  Chennai Super Kings
# 893   336039     Mumbai  2008-05-31  2007/08  Semi Final  Chennai Super Kings
# 733   501240    Chennai  2011-05-04     2011          43  Chennai Super Kings
# 892   336040     Mumbai  2008-06-01  2007/08       Final  Chennai Super Kings
# ..       ...        ...         ...      ...         ...                  ...
# 372  1082591  Hyderabad  2017-04-05     2017           1  Sunrisers Hyderabad
# 513   734007  Hyderabad  2014-05-14     2014          39  Sunrisers Hyderabad
# 510   734015  Hyderabad  2014-05-18     2014          43  Sunrisers Hyderabad
# 421   980923  Hyderabad  2016-04-18     2016          12  Sunrisers Hyderabad
# 213  1178416    Chennai  2019-04-23     2019          41  Sunrisers Hyderabad
#
# ...

# %%
students = [
    ['Ali', 20, 'Lahore', 'Yes'],
    ['Sara', 25, 'Karachi', 'Yes'],
    ['John', 22, 'Islamabad', np.nan],
    [np.nan, np.nan, np.nan, np.nan]


]

df = pd.DataFrame(students, columns=['Name', 'Age', 'City', 'Student'])
df
# Out:
#    Name   Age       City Student
# 0   Ali  20.0     Lahore     Yes
# 1  Sara  25.0    Karachi     Yes
# 2  John  22.0  Islamabad     NaN
# 3   NaN   NaN        NaN     NaN

# %% [markdown]
# ### multiple cols sorting

# %%
ipl.sort_values(['Team1', 'Team2'])
# Out:
#           ID         City        Date   Season MatchNumber  \
# 658   548352      Chennai  2012-05-04     2012          46
# 738   501236      Chennai  2011-05-01     2011          39
# 777   419163       Mumbai  2010-04-22  2009/10  Semi Final
# 831   419110      Chennai  2010-03-14  2009/10           5
# 865   392209  East London  2009-05-04     2009          29
# ..       ...          ...         ...      ...         ...
# 372  1082591    Hyderabad  2017-04-05     2017           1
# 407   980953    Hyderabad  2016-04-30     2016          27
# 441   829807    Hyderabad  2015-05-15     2015          52
# 506   734021    Hyderabad  2014-05-20     2014          46
# 621   598004    Hyderabad  2013-04-07     2013           7
#
#                    Team1                        Team2  \
# 658  Chennai Super Kings              Deccan Chargers
# 738  Chennai Super Kings              Deccan Chargers
# 777  Chennai Super Kings              Deccan Chargers
# ...

# %% [markdown]
# ### rank (series)

# %%
ipl['team_rank'] = ipl['MatchNumber'].rank(ascending=False)
ipl.sort_values('team_rank')
# Out:
#           ID          City        Date   Season MatchNumber  \
# 777   419163        Mumbai  2010-04-22  2009/10  Semi Final
# 778   419162        Mumbai  2010-04-21  2009/10  Semi Final
# 837   392237     Centurion  2009-05-22     2009  Semi Final
# 836   392238  Johannesburg  2009-05-23     2009  Semi Final
# 893   336039        Mumbai  2008-05-31  2007/08  Semi Final
# ..       ...           ...         ...      ...         ...
# 133  1254058       Chennai  2021-04-09     2021           1
# 193  1216492     Abu Dhabi  2020-09-19  2020/21           1
# 891   392181     Cape Town  2009-04-18     2009           1
# 253  1175356       Chennai  2019-03-23     2019           1
# 73   1304047        Mumbai  2022-03-26     2022           1
#
#                            Team1                        Team2  \
# 777          Chennai Super Kings              Deccan Chargers
# 778  Royal Challengers Bangalore               Mumbai Indians
# ...

# %%
#series to dataframe

x.reset_index()
# Out:
#    index   0
# 0      0   5
# 1      1   4
# 2      2   7
# 3      3  33
# 4      4   7
# 5      5  86

# %%
#unique

x.unique()
# Out:
# array([ 5,  4,  7, 33, 86])

# %% [markdown]
# ## groupby function

# %%
genres =movies.groupby('genres')

# %%
genres.sum()
# Out:
#                                                                       title_x  \
# genres
# Action                      Dabangg 3Aa Gaya HeroGabbar Is BackGabbar Is B...
# Action|Adventure                Junglee (2019 film)Thugs of HindostanZokkomon
# Action|Adventure|Animation  Arjun: The Warrior PrinceKrishna Aur KansToonp...
# Action|Adventure|Comedy     Total DhamaalJagga JasoosDishoomA Flying JattB...
# Action|Adventure|Crime                                              Jai Veeru
# ...                                                                       ...
# Romance|Thriller            Valentine's NightCigarette Ki TarahAggar (film...
# Sci-Fi                                                          Aalaap (film)
# Sport                                                                22 Yards
# Thriller                    RisknamaaSetters (film)Yeh Saali AashiquiMy Bi...
# War                                                             Battalion 609
#
# ...
